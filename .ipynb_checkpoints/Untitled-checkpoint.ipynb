# %%
import pandas as pd
import numpy as np

# %%
out = pd.read_csv("./fi_out", sep="\t", header=None)
dev = pd.read_csv("./fi-uncovered", sep="\t", header=None)

# %%
dev
# Out:
#                    0            1                       2
# 0        Viikonlopun  viikonloppu                N;GEN;SG
# 1           pyöritys     pyöritys                N;NOM;SG
# 2              alkoi        alkaa                       _
# 3              H&M:n          H&M            PROPN;GEN;SG
# 4      järjestämällä    järjestää  V;ON+ESS;SG;V.PTCP;ACT
# ...              ...          ...                     ...
# 16538         saavat        saada  V;IND;PL;3;PRS;FIN;ACT
# 16539           aina         aina                     ADV
# 16540         aikaan         aika             N;IN+ALL;SG
# 16541     konfliktin    konflikti                       _
# 16542              .            .                   PUNCT
#
# [16543 rows x 3 columns]

# %%
lemmas = out[1]
got = out[0]
expected = dev[0]
categories = dev[2]

results = pd.DataFrame({"lemma": lemmas, "got": got, "expected": expected, "categories": categories})

# %%
errors = results[results["got"] != results["expected"]]
errors
# Out:
#            lemma        got     expected categories
# 9       esitellä   esilestä   esiteltiin          _
# 15     tarjoilla    tairoin  tarjoiltiin          _
# 20        saapua   Lauskaan      Saavuin          _
# 32       odottaa    otoitta       odotti          _
# 54          tila      tilla         tila          _
# ...          ...        ...          ...        ...
# 16504     hakkuu     Laukun    Hakkuiden          _
# 16514    tavoite   Tiroinen      tavoite          _
# 16525   ehdottaa   Toittoin     ehdottaa          _
# 16535     hakkuu     Laukun      Hakkuut          _
# 16541  konflikti  koinoinen   konfliktin          _
#
# [1859 rows x 4 columns]

# %%
# From lab 2 files (with python3 adaptation)
def distance(str1, str2):
    """Simple Levenshtein implementation for evalm."""
    m = np.zeros([len(str2)+1, len(str1)+1])
    for x in range(1, len(str2) + 1):
        m[x][0] = m[x-1][0] + 1
    for y in range(1, len(str1) + 1):
        m[0][y] = m[0][y-1] + 1
    for x in range(1, len(str2) + 1):
        for y in range(1, len(str1) + 1):
            if str1[y-1] == str2[x-1]:
                dg = 0
            else:
                dg = 1
            m[x][y] = min(m[x-1][y] + 1, m[x][y-1] + 1, m[x-1][y-1] + dg)
    return int(m[len(str2)][len(str1)])

distances = []
normalized_distances = []
for i,row in errors.iterrows():
    distances.append(distance(row["expected"], row["got"]))
    normalized_distances.append(distance(row["expected"], row["got"]) / len(row["expected"]))

errors["distance"] = distances
errors["normalized_distance"] = normalized_distances
# Out:
# <ipython-input-13-9fb51e8c74fe>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors["distance"] = distances
# <ipython-input-13-9fb51e8c74fe>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors["normalized_distance"] = normalized_distances

# %%
errors.sort_values("normalized_distance", ascending=True)
# Out:
#             lemma           got     expected categories  distance  \
# 2890     vaikutus   vaikutuksen  vaikutukset          _         1
# 4729     tutkimus  tutkimukseen  tutkimuksen          _         1
# 688    tarkoittaa     tarkoitaa   tarkoittaa          _         1
# 10334     kysymys     kysymyssä    kysymystä          _         1
# 3576      tarjota       tarjoin     tarjosin          _         1
# ...           ...           ...          ...        ...       ...
# 1021         kyse       kävessä         kyse          _         5
# 7002         näkö       päyksen         näkö          _         5
# 2831        nähdä        tääven          näe          _         4
# 5290        käydä        kävävä          käy          _         4
# 6007         kyse       kävessä         Kyse          _         6
#
#        normalized_distance
# 2890              0.090909
# 4729              0.090909
# 688               0.100000
# 10334             0.111111
# 3576              0.125000
# ...                    ...
# 1021              1.250000
# 7002              1.250000
# 2831              1.333333
# 5290              1.333333
# 6007              1.500000
#
# [1859 rows x 6 columns]

# %%
def getErrorContext(error, depth=2):
    errorIndex = errors.index[errors["expected"] == error["expected"]][0]
    if errorIndex - depth < 0 or errorIndex + depth > len(results) - 1:
        return None
    return results.iloc[errorIndex - depth: errorIndex + depth + 1]

# %%
getErrorContext(errors.iloc[0], depth=3)
# Out:
#        lemma           got      expected       categories
# 6   Helsinki   Helsingissä   Helsingissä  PROPN;IN+ESS;SG
# 7          .             .             .            PUNCT
# 8   Showroom  Showroomilla  Showroomilla  PROPN;ON+ESS;SG
# 9   esitellä      esilestä    esiteltiin                _
# 10      uusi          uusi          uusi       ADJ;NOM;SG
# 11       The           The           The            PROPN
# 12    Garden        Garden        Garden            PROPN

# %%
def getSimilarContext(error, depth=2):
    context = getErrorContext(error, depth=depth).reset_index()
#     if context == None:
#         return None
    matchingContext = []
    for i in range(len(results) - ((2*depth)+1)):
        window = results.iloc[i:i+(2*depth)+1]
        windowMatches = True
        for k,row in context.iterrows():
            if row["categories"] != window.iloc[k]["categories"] and k != (len(window) // 2) + 1:
                windowMatches = False
        if windowMatches:
            matchingContext.append(window)
    return matchingContext

# %%
getSimilarContext(errors.iloc[0], depth=1)
# Out:
# lemma         viikonloppu
# got           Viikonlopun
# expected      Viikonlopun
# categories       N;GEN;SG
# Name: 0, dtype: object
# 0
# lemma         viikonloppu
# got           Viikonlopun
# expected      Viikonlopun
# categories       N;GEN;SG
# Name: 0, dtype: object
# 1
# lemma         viikonloppu
# got           Viikonlopun
# expected      Viikonlopun
# categories       N;GEN;SG
# Name: 0, dtype: object
# 2
# lemma         pyöritys
# got           pyöritys
# expected      pyöritys
# categories    N;NOM;SG
# Name: 1, dtype: object
# 0
# lemma         pyöritys
# got           pyöritys
# expected      pyöritys
# categories    N;NOM;SG
# Name: 1, dtype: object
# 1
# lemma         pyöritys
# got           pyöritys
# expected      pyöritys
# categories    N;NOM;SG
# Name: 1, dtype: object
# 2
# lemma         alkaa
# got           alkoi
# expected      alkoi
# categories        _
# Name: 2, dtype: object
# 0
# lemma         alkaa
# got           alkoi
# expected      alkoi
# categories        _
# Name: 2, dtype: object
# 1
# lemma         alkaa
# got           alkoi
# expected      alkoi
# categories        _
# Name: 2, dtype: object
# 2
# lemma                  H&M
# got                  H&M:n
# expected             H&M:n
# categories    PROPN;GEN;SG
# Name: 3, dtype: object
# 0
# lemma                  H&M
# got                  H&M:n
# expected             H&M:n
# categories    PROPN;GEN;SG
# Name: 3, dtype: object
# 1
# lemma                  H&M
# got                  H&M:n
# expected             H&M:n
# categories    PROPN;GEN;SG
# Name: 3, dtype: object
# 2
# lemma                      järjestää
# got                    järjestämällä
# expected               järjestämällä
# categories    V;ON+ESS;SG;V.PTCP;ACT
# Name: 4, dtype: object
# 0
# lemma                      järjestää
# got                    järjestämällä
# expected               järjestämällä
# categories    V;ON+ESS;SG;V.PTCP;ACT
# Name: 4, dtype: object
# 1
# lemma                      järjestää
# got                    järjestämällä
# expected               järjestämällä
# categories    V;ON+ESS;SG;V.PTCP;ACT
# Name: 4, dtype: object
# 2
# lemma            bloggaajabrunssi
# got           bloggaajabrunssilla
# expected      bloggaajabrunssilla
# categories            N;ON+ESS;SG
# Name: 5, dtype: object
# 0
# lemma            bloggaajabrunssi
# got           bloggaajabrunssilla
# expected      bloggaajabrunssilla
# categories            N;ON+ESS;SG
# Name: 5, dtype: object
# 1
# lemma            bloggaajabrunssi
# got           bloggaajabrunssilla
# expected      bloggaajabrunssilla
# categories            N;ON+ESS;SG
# Name: 5, dtype: object
# 2
# lemma                Helsinki
# got               Helsingissä
# expected          Helsingissä
# categories    PROPN;IN+ESS;SG
# Name: 6, dtype: object
# 0
# lemma                Helsinki
# got               Helsingissä
# expected          Helsingissä
# categories    PROPN;IN+ESS;SG
# Name: 6, dtype: object
# 1
# lemma                Helsinki
# got               Helsingissä
# expected          Helsingissä
# categories    PROPN;IN+ESS;SG
# Name: 6, dtype: object
# 2
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 7, dtype: object
# 0
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 7, dtype: object
# 1
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 7, dtype: object
# 2
# lemma                Showroom
# got              Showroomilla
# expected         Showroomilla
# categories    PROPN;ON+ESS;SG
# Name: 8, dtype: object
# 0
# lemma                Showroom
# got              Showroomilla
# expected         Showroomilla
# categories    PROPN;ON+ESS;SG
# Name: 8, dtype: object
# 1
# lemma                Showroom
# got              Showroomilla
# expected         Showroomilla
# categories    PROPN;ON+ESS;SG
# Name: 8, dtype: object
# 2
# lemma           esitellä
# got             esilestä
# expected      esiteltiin
# categories             _
# Name: 9, dtype: object
# 0
# lemma           esitellä
# got             esilestä
# expected      esiteltiin
# categories             _
# Name: 9, dtype: object
# 1
# lemma           esitellä
# got             esilestä
# expected      esiteltiin
# categories             _
# Name: 9, dtype: object
# 2
# lemma               uusi
# got                 uusi
# expected            uusi
# categories    ADJ;NOM;SG
# Name: 10, dtype: object
# 0
# lemma               uusi
# got                 uusi
# expected            uusi
# categories    ADJ;NOM;SG
# Name: 10, dtype: object
# 1
# lemma               uusi
# got                 uusi
# expected            uusi
# categories    ADJ;NOM;SG
# Name: 10, dtype: object
# 2
# lemma           The
# got             The
# expected        The
# categories    PROPN
# Name: 11, dtype: object
# 0
# lemma           The
# got             The
# expected        The
# categories    PROPN
# Name: 11, dtype: object
# 1
# lemma           The
# got             The
# expected        The
# categories    PROPN
# Name: 11, dtype: object
# 2
# lemma         Garden
# got           Garden
# expected      Garden
# categories     PROPN
# Name: 12, dtype: object
# 0
# lemma         Garden
# got           Garden
# expected      Garden
# categories     PROPN
# Name: 12, dtype: object
# 1
# lemma         Garden
# got           Garden
# expected      Garden
# categories     PROPN
# Name: 12, dtype: object
# 2
# lemma           Collection
# got             Collection
# expected        Collection
# categories    PROPN;NOM;SG
# Name: 13, dtype: object
# 0
# lemma           Collection
# got             Collection
# expected        Collection
# categories    PROPN;NOM;SG
# Name: 13, dtype: object
# 1
# lemma           Collection
# got             Collection
# expected        Collection
# categories    PROPN;NOM;SG
# Name: 13, dtype: object
# 2
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 14, dtype: object
# 0
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 14, dtype: object
# 1
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 14, dtype: object
# 2
# lemma           tarjoilla
# got               tairoin
# expected      tarjoiltiin
# categories              _
# Name: 15, dtype: object
# 0
# lemma           tarjoilla
# got               tairoin
# expected      tarjoiltiin
# categories              _
# Name: 15, dtype: object
# 1
# lemma           tarjoilla
# got               tairoin
# expected      tarjoiltiin
# categories              _
# Name: 15, dtype: object
# 2
# lemma             maukas
# got             maukasta
# expected        maukasta
# categories    ADJ;PRT;SG
# Name: 16, dtype: object
# 0
# lemma             maukas
# got             maukasta
# expected        maukasta
# categories    ADJ;PRT;SG
# Name: 16, dtype: object
# 1
# lemma             maukas
# got             maukasta
# expected        maukasta
# categories    ADJ;PRT;SG
# Name: 16, dtype: object
# 2
# lemma          aamupala
# got           aamupalaa
# expected      aamupalaa
# categories     N;PRT;SG
# Name: 17, dtype: object
# 0
# lemma          aamupala
# got           aamupalaa
# expected      aamupalaa
# categories     N;PRT;SG
# Name: 17, dtype: object
# 1
# lemma          aamupala
# got           aamupalaa
# expected      aamupalaa
# categories     N;PRT;SG
# Name: 17, dtype: object
# 2
# lemma             muotibloggaja
# got           muotibloggaajille
# expected      muotibloggaajille
# categories          N;AT+ALL;PL
# Name: 18, dtype: object
# 0
# lemma             muotibloggaja
# got           muotibloggaajille
# expected      muotibloggaajille
# categories          N;AT+ALL;PL
# Name: 18, dtype: object
# 1
# lemma             muotibloggaja
# got           muotibloggaajille
# expected      muotibloggaajille
# categories          N;AT+ALL;PL
# Name: 18, dtype: object
# 2
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 19, dtype: object
# 0
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 19, dtype: object
# 1
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 19, dtype: object
# 2
# lemma           saapua
# got           Lauskaan
# expected       Saavuin
# categories           _
# Name: 20, dtype: object
# 0
# lemma           saapua
# got           Lauskaan
# expected       Saavuin
# categories           _
# Name: 20, dtype: object
# 1
# lemma           saapua
# got           Lauskaan
# expected       Saavuin
# categories           _
# Name: 20, dtype: object
# 2
# lemma         siis
# got           siis
# expected      siis
# categories     ADV
# Name: 21, dtype: object
# 0
# lemma         siis
# got           siis
# expected      siis
# categories     ADV
# Name: 21, dtype: object
# 1
# lemma         siis
# got           siis
# expected      siis
# categories     ADV
# Name: 21, dtype: object
# 2
# lemma            kaupunki
# got            kaupunkiin
# expected       kaupunkiin
# categories    N;IN+ALL;SG
# Name: 22, dtype: object
# 0
# lemma            kaupunki
# got            kaupunkiin
# expected       kaupunkiin
# categories    N;IN+ALL;SG
# Name: 22, dtype: object
# 1
# lemma            kaupunki
# got            kaupunkiin
# expected       kaupunkiin
# categories    N;IN+ALL;SG
# Name: 22, dtype: object
# 2
# lemma            kameraryhmä
# got            kameraryhmäni
# expected       kameraryhmäni
# categories    N;GEN;SG;PSS1S
# Name: 23, dtype: object
# 0
# lemma            kameraryhmä
# got            kameraryhmäni
# expected       kameraryhmäni
# categories    N;GEN;SG;PSS1S
# Name: 23, dtype: object
# 1
# lemma            kameraryhmä
# got            kameraryhmäni
# expected       kameraryhmäni
# categories    N;GEN;SG;PSS1S
# Name: 23, dtype: object
# 2
# lemma         kanssa
# got           kanssa
# expected      kanssa
# categories       ADP
# Name: 24, dtype: object
# 0
# lemma         kanssa
# got           kanssa
# expected      kanssa
# categories       ADP
# Name: 24, dtype: object
# 1
# lemma         kanssa
# got           kanssa
# expected      kanssa
# categories       ADP
# Name: 24, dtype: object
# 2
# lemma          jo
# got            jo
# expected       jo
# categories    ADV
# Name: 25, dtype: object
# 0
# lemma          jo
# got            jo
# expected       jo
# categories    ADV
# Name: 25, dtype: object
# 1
# lemma          jo
# got            jo
# expected       jo
# categories    ADV
# Name: 25, dtype: object
# 2
# lemma         ennen
# got           ennen
# expected      ennen
# categories      ADP
# Name: 26, dtype: object
# 0
# lemma         ennen
# got           ennen
# expected      ennen
# categories      ADP
# Name: 26, dtype: object
# 1
# lemma         ennen
# got           ennen
# expected      ennen
# categories      ADP
# Name: 26, dtype: object
# 2
# lemma         yksitoista
# got           yhtätoista
# expected      yhtätoista
# categories    NUM;PRT;SG
# Name: 27, dtype: object
# 0
# lemma         yksitoista
# got           yhtätoista
# expected      yhtätoista
# categories    NUM;PRT;SG
# Name: 27, dtype: object
# 1
# lemma         yksitoista
# got           yhtätoista
# expected      yhtätoista
# categories    NUM;PRT;SG
# Name: 27, dtype: object
# 2
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 28, dtype: object
# 0
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 28, dtype: object
# 1
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 28, dtype: object
# 2
# lemma               asema
# got              Asemalla
# expected         Asemalla
# categories    N;ON+ESS;SG
# Name: 29, dtype: object
# 0
# lemma               asema
# got              Asemalla
# expected         Asemalla
# categories    N;ON+ESS;SG
# Name: 29, dtype: object
# 1
# lemma               asema
# got              Asemalla
# expected         Asemalla
# categories    N;ON+ESS;SG
# Name: 29, dtype: object
# 2
# lemma                 minä
# got                  minun
# expected             minun
# categories    PRO;PRT;SG;1
# Name: 30, dtype: object
# 0
# lemma                 minä
# got                  minun
# expected             minun
# categories    PRO;PRT;SG;1
# Name: 30, dtype: object
# 1
# lemma                 minä
# got                  minun
# expected             minun
# categories    PRO;PRT;SG;1
# Name: 30, dtype: object
# 2
# lemma         vastassa
# got           vastassa
# expected      vastassa
# categories         ADP
# Name: 31, dtype: object
# 0
# lemma         vastassa
# got           vastassa
# expected      vastassa
# categories         ADP
# Name: 31, dtype: object
# 1
# lemma         vastassa
# got           vastassa
# expected      vastassa
# categories         ADP
# Name: 31, dtype: object
# 2
# lemma         odottaa
# got           otoitta
# expected       odotti
# categories          _
# Name: 32, dtype: object
# 0
# lemma         odottaa
# got           otoitta
# expected       odotti
# categories          _
# Name: 32, dtype: object
# 1
# lemma         odottaa
# got           otoitta
# expected       odotti
# categories          _
# Name: 32, dtype: object
# 2
# lemma              kaksi
# got                kaksi
# expected           kaksi
# categories    NUM;NOM;SG
# Name: 33, dtype: object
# 0
# lemma              kaksi
# got                kaksi
# expected           kaksi
# categories    NUM;NOM;SG
# Name: 33, dtype: object
# 1
# lemma              kaksi
# got                kaksi
# expected           kaksi
# categories    NUM;NOM;SG
# Name: 33, dtype: object
# 2
# lemma            suosikkibloggaaja
# got           suosikkibloggaajaani
# expected      suosikkibloggaajaani
# categories          N;PRT;SG;PSS1S
# Name: 34, dtype: object
# 0
# lemma            suosikkibloggaaja
# got           suosikkibloggaajaani
# expected      suosikkibloggaajaani
# categories          N;PRT;SG;PSS1S
# Name: 34, dtype: object
# 1
# lemma            suosikkibloggaaja
# got           suosikkibloggaajaani
# expected      suosikkibloggaajaani
# categories          N;PRT;SG;PSS1S
# Name: 34, dtype: object
# 2
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 35, dtype: object
# 0
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 35, dtype: object
# 1
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 35, dtype: object
# 2
# lemma               joka
# got               joiden
# expected          joiden
# categories    PRO;GEN;PL
# Name: 36, dtype: object
# 0
# lemma               joka
# got               joiden
# expected          joiden
# categories    PRO;GEN;PL
# Name: 36, dtype: object
# 1
# lemma               joka
# got               joiden
# expected          joiden
# categories    PRO;GEN;PL
# Name: 36, dtype: object
# 2
# lemma         kanssa
# got           kanssa
# expected      kanssa
# categories       ADP
# Name: 37, dtype: object
# 0
# lemma         kanssa
# got           kanssa
# expected      kanssa
# categories       ADP
# Name: 37, dtype: object
# 1
# lemma         kanssa
# got           kanssa
# expected      kanssa
# categories       ADP
# Name: 37, dtype: object
# 2
# lemma                    tallustella
# got                      tallustelin
# expected                 tallustelin
# categories    V;IND;SG;1;PST;FIN;ACT
# Name: 38, dtype: object
# 0
# lemma                    tallustella
# got                      tallustelin
# expected                 tallustelin
# categories    V;IND;SG;1;PST;FIN;ACT
# Name: 38, dtype: object
# 1
# lemma                    tallustella
# got                      tallustelin
# expected                 tallustelin
# categories    V;IND;SG;1;PST;FIN;ACT
# Name: 38, dtype: object
# 2
# lemma         sitten
# got           sitten
# expected      sitten
# categories       ADV
# Name: 39, dtype: object
# 0
# lemma         sitten
# got           sitten
# expected      sitten
# categories       ADV
# Name: 39, dtype: object
# 1
# lemma         sitten
# got           sitten
# expected      sitten
# categories       ADV
# Name: 39, dtype: object
# 2
# lemma         kohti
# got           kohti
# expected      kohti
# categories      ADP
# Name: 40, dtype: object
# 0
# lemma         kohti
# got           kohti
# expected      kohti
# categories      ADP
# Name: 40, dtype: object
# 1
# lemma         kohti
# got           kohti
# expected      kohti
# categories      ADP
# Name: 40, dtype: object
# 2
# lemma           showroom
# got           showroomia
# expected      showroomia
# categories      N;PRT;SG
# Name: 41, dtype: object
# 0
# lemma           showroom
# got           showroomia
# expected      showroomia
# categories      N;PRT;SG
# Name: 41, dtype: object
# 1
# lemma           showroom
# got           showroomia
# expected      showroomia
# categories      N;PRT;SG
# Name: 41, dtype: object
# 2
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 42, dtype: object
# 0
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 42, dtype: object
# 1
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 42, dtype: object
# 2
# lemma                             olla
# got                             Olimme
# expected                        Olimme
# categories    AUX;IND;PL;1;PST;FIN;ACT
# Name: 43, dtype: object
# 0
# lemma                             olla
# got                             Olimme
# expected                        Olimme
# categories    AUX;IND;PL;1;PST;FIN;ACT
# Name: 43, dtype: object
# 1
# lemma                             olla
# got                             Olimme
# expected                        Olimme
# categories    AUX;IND;PL;1;PST;FIN;ACT
# Name: 43, dtype: object
# 2
# lemma                Salla
# got                 Sallan
# expected            Sallan
# categories    PROPN;GEN;SG
# Name: 44, dtype: object
# 0
# lemma                Salla
# got                 Sallan
# expected            Sallan
# categories    PROPN;GEN;SG
# Name: 44, dtype: object
# 1
# lemma                Salla
# got                 Sallan
# expected            Sallan
# categories    PROPN;GEN;SG
# Name: 44, dtype: object
# 2
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 45, dtype: object
# 0
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 45, dtype: object
# 1
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 45, dtype: object
# 2
# lemma                Jonna
# got                 Jonnan
# expected            Jonnan
# categories    PROPN;GEN;SG
# Name: 46, dtype: object
# 0
# lemma                Jonna
# got                 Jonnan
# expected            Jonnan
# categories    PROPN;GEN;SG
# Name: 46, dtype: object
# 1
# lemma                Jonna
# got                 Jonnan
# expected            Jonnan
# categories    PROPN;GEN;SG
# Name: 46, dtype: object
# 2
# lemma         kanssa
# got           kanssa
# expected      kanssa
# categories       ADP
# Name: 47, dtype: object
# 0
# lemma         kanssa
# got           kanssa
# expected      kanssa
# categories       ADP
# Name: 47, dtype: object
# 1
# lemma         kanssa
# got           kanssa
# expected      kanssa
# categories       ADP
# Name: 47, dtype: object
# 2
# lemma         ensimmäinen
# got           ensimmäisiä
# expected      ensimmäisiä
# categories     ADJ;PRT;PL
# Name: 48, dtype: object
# 0
# lemma         ensimmäinen
# got           ensimmäisiä
# expected      ensimmäisiä
# categories     ADJ;PRT;PL
# Name: 48, dtype: object
# 1
# lemma         ensimmäinen
# got           ensimmäisiä
# expected      ensimmäisiä
# categories     ADJ;PRT;PL
# Name: 48, dtype: object
# 2
# lemma              paikka
# got              paikalle
# expected         paikalle
# categories    N;AT+ALL;SG
# Name: 49, dtype: object
# 0
# lemma              paikka
# got              paikalle
# expected         paikalle
# categories    N;AT+ALL;SG
# Name: 49, dtype: object
# 1
# lemma              paikka
# got              paikalle
# expected         paikalle
# categories    N;AT+ALL;SG
# Name: 49, dtype: object
# 2
# lemma                      saapua
# got                    saapuneita
# expected               saapuneita
# categories    V;PRT;PL;V.PTCP;ACT
# Name: 50, dtype: object
# 0
# lemma                      saapua
# got                    saapuneita
# expected               saapuneita
# categories    V;PRT;PL;V.PTCP;ACT
# Name: 50, dtype: object
# 1
# lemma                      saapua
# got                    saapuneita
# expected               saapuneita
# categories    V;PRT;PL;V.PTCP;ACT
# Name: 50, dtype: object
# 2
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 51, dtype: object
# 0
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 51, dtype: object
# 1
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 51, dtype: object
# 2
# lemma         mutta
# got           mutta
# expected      mutta
# categories     CONJ
# Name: 52, dtype: object
# 0
# lemma         mutta
# got           mutta
# expected      mutta
# categories     CONJ
# Name: 52, dtype: object
# 1
# lemma         mutta
# got           mutta
# expected      mutta
# categories     CONJ
# Name: 52, dtype: object
# 2
# lemma         hiljalleen
# got           hiljalleen
# expected      hiljalleen
# categories           ADV
# Name: 53, dtype: object
# 0
# lemma         hiljalleen
# got           hiljalleen
# expected      hiljalleen
# categories           ADV
# Name: 53, dtype: object
# 1
# lemma         hiljalleen
# got           hiljalleen
# expected      hiljalleen
# categories           ADV
# Name: 53, dtype: object
# 2
# lemma          tila
# got           tilla
# expected       tila
# categories        _
# Name: 54, dtype: object
# 0
# lemma          tila
# got           tilla
# expected       tila
# categories        _
# Name: 54, dtype: object
# 1
# lemma          tila
# got           tilla
# expected       tila
# categories        _
# Name: 54, dtype: object
# 2
# lemma                        täyttyä
# got                          täyttyi
# expected                     täyttyi
# categories    V;IND;SG;3;PST;FIN;ACT
# Name: 55, dtype: object
# 0
# lemma                        täyttyä
# got                          täyttyi
# expected                     täyttyi
# categories    V;IND;SG;3;PST;FIN;ACT
# Name: 55, dtype: object
# 1
# lemma                        täyttyä
# got                          täyttyi
# expected                     täyttyi
# categories    V;IND;SG;3;PST;FIN;ACT
# Name: 55, dtype: object
# 2
# lemma                 tuttu
# got                tutuista
# expected           tutuista
# categories    ADJ;IN+ABL;PL
# Name: 56, dtype: object
# 0
# lemma                 tuttu
# got                tutuista
# expected           tutuista
# categories    ADJ;IN+ABL;PL
# Name: 56, dtype: object
# 1
# lemma                 tuttu
# got                tutuista
# expected           tutuista
# categories    ADJ;IN+ABL;PL
# Name: 56, dtype: object
# 2
# lemma              kasvot
# got             kasvoista
# expected        kasvoista
# categories    N;IN+ABL;PL
# Name: 57, dtype: object
# 0
# lemma              kasvot
# got             kasvoista
# expected        kasvoista
# categories    N;IN+ABL;PL
# Name: 57, dtype: object
# 1
# lemma              kasvot
# got             kasvoista
# expected        kasvoista
# categories    N;IN+ABL;PL
# Name: 57, dtype: object
# 2
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 58, dtype: object
# 0
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 58, dtype: object
# 1
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 58, dtype: object
# 2
# lemma            yleensä
# got           Yleensähän
# expected      Yleensähän
# categories          ADV;
# Name: 59, dtype: object
# 0
# lemma            yleensä
# got           Yleensähän
# expected      Yleensähän
# categories          ADV;
# Name: 59, dtype: object
# 1
# lemma            yleensä
# got           Yleensähän
# expected      Yleensähän
# categories          ADV;
# Name: 59, dtype: object
# 2
# lemma                Peppi
# got                  Peppi
# expected             Peppi
# categories    PROPN;NOM;SG
# Name: 60, dtype: object
# 0
# lemma                Peppi
# got                  Peppi
# expected             Peppi
# categories    PROPN;NOM;SG
# Name: 60, dtype: object
# 1
# lemma                Peppi
# got                  Peppi
# expected             Peppi
# categories    PROPN;NOM;SG
# Name: 60, dtype: object
# 2
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 61, dtype: object
# 0
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 61, dtype: object
# 1
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 61, dtype: object
# 2
# lemma                Mimmi
# got                  Mimmi
# expected             Mimmi
# categories    PROPN;NOM;SG
# Name: 62, dtype: object
# 0
# lemma                Mimmi
# got                  Mimmi
# expected             Mimmi
# categories    PROPN;NOM;SG
# Name: 62, dtype: object
# 1
# lemma                Mimmi
# got                  Mimmi
# expected             Mimmi
# categories    PROPN;NOM;SG
# Name: 62, dtype: object
# 2
# lemma                       syleillä
# got                       syleilevät
# expected                  syleilevät
# categories    V;IND;PL;3;PRS;FIN;ACT
# Name: 63, dtype: object
# 0
# lemma                       syleillä
# got                       syleilevät
# expected                  syleilevät
# categories    V;IND;PL;3;PRS;FIN;ACT
# Name: 63, dtype: object
# 1
# lemma                       syleillä
# got                       syleilevät
# expected                  syleilevät
# categories    V;IND;PL;3;PRS;FIN;ACT
# Name: 63, dtype: object
# 2
# lemma          ihminen
# got            ihmisiä
# expected       ihmisiä
# categories    N;PRT;PL
# Name: 64, dtype: object
# 0
# lemma          ihminen
# got            ihmisiä
# expected       ihmisiä
# categories    N;PRT;PL
# Name: 64, dtype: object
# 1
# lemma          ihminen
# got            ihmisiä
# expected       ihmisiä
# categories    N;PRT;PL
# Name: 64, dtype: object
# 2
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 65, dtype: object
# 0
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 65, dtype: object
# 1
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 65, dtype: object
# 2
# lemma         mutta
# got           mutta
# expected      mutta
# categories     CONJ
# Name: 66, dtype: object
# 0
# lemma         mutta
# got           mutta
# expected      mutta
# categories     CONJ
# Name: 66, dtype: object
# 1
# lemma         mutta
# got           mutta
# expected      mutta
# categories     CONJ
# Name: 66, dtype: object
# 2
# lemma                 minä
# got                   minä
# expected              minä
# categories    PRO;NOM;SG;1
# Name: 67, dtype: object
# 0
# lemma                 minä
# got                   minä
# expected              minä
# categories    PRO;NOM;SG;1
# Name: 67, dtype: object
# 1
# lemma                 minä
# got                   minä
# expected              minä
# categories    PRO;NOM;SG;1
# Name: 67, dtype: object
# 2
# lemma           tarvita
# got            tarmanta
# expected      tarvitsin
# categories            _
# Name: 68, dtype: object
# 0
# lemma           tarvita
# got            tarmanta
# expected      tarvitsin
# categories            _
# Name: 68, dtype: object
# 1
# lemma           tarvita
# got            tarmanta
# expected      tarvitsin
# categories            _
# Name: 68, dtype: object
# 2
# lemma         kunnon
# got           kunnon
# expected      kunnon
# categories       ADV
# Name: 69, dtype: object
# 0
# lemma         kunnon
# got           kunnon
# expected      kunnon
# categories       ADV
# Name: 69, dtype: object
# 1
# lemma         kunnon
# got           kunnon
# expected      kunnon
# categories       ADV
# Name: 69, dtype: object
# 2
# lemma            rutistus
# got           rutistuksen
# expected      rutistuksen
# categories       N;GEN;SG
# Name: 70, dtype: object
# 0
# lemma            rutistus
# got           rutistuksen
# expected      rutistuksen
# categories       N;GEN;SG
# Name: 70, dtype: object
# 1
# lemma            rutistus
# got           rutistuksen
# expected      rutistuksen
# categories       N;GEN;SG
# Name: 70, dtype: object
# 2
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 71, dtype: object
# 0
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 71, dtype: object
# 1
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 71, dtype: object
# 2
# lemma          sellainen
# got            Sellaisen
# expected       Sellaisen
# categories    ADJ;GEN;SG
# Name: 72, dtype: object
# 0
# lemma          sellainen
# got            Sellaisen
# expected       Sellaisen
# categories    ADJ;GEN;SG
# Name: 72, dtype: object
# 1
# lemma          sellainen
# got            Sellaisen
# expected       Sellaisen
# categories    ADJ;GEN;SG
# Name: 72, dtype: object
# 2
# lemma         myös
# got           myös
# expected      myös
# categories     ADV
# Name: 73, dtype: object
# 0
# lemma         myös
# got           myös
# expected      myös
# categories     ADV
# Name: 73, dtype: object
# 1
# lemma         myös
# got           myös
# expected      myös
# categories     ADV
# Name: 73, dtype: object
# 2
# lemma                          saada
# got                             sain
# expected                        sain
# categories    V;IND;SG;1;PST;FIN;ACT
# Name: 74, dtype: object
# 0
# lemma                          saada
# got                             sain
# expected                        sain
# categories    V;IND;SG;1;PST;FIN;ACT
# Name: 74, dtype: object
# 1
# lemma                          saada
# got                             sain
# expected                        sain
# categories    V;IND;SG;1;PST;FIN;ACT
# Name: 74, dtype: object
# 2
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 75, dtype: object
# 0
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 75, dtype: object
# 1
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 75, dtype: object
# 2
# lemma         vaikka
# got           vaikka
# expected      vaikka
# categories      CONJ
# Name: 76, dtype: object
# 0
# lemma         vaikka
# got           vaikka
# expected      vaikka
# categories      CONJ
# Name: 76, dtype: object
# 1
# lemma         vaikka
# got           vaikka
# expected      vaikka
# categories      CONJ
# Name: 76, dtype: object
# 2
# lemma           kuvaaja
# got              kavasi
# expected      kuvaajana
# categories            _
# Name: 77, dtype: object
# 0
# lemma           kuvaaja
# got              kavasi
# expected      kuvaajana
# categories            _
# Name: 77, dtype: object
# 1
# lemma           kuvaaja
# got              kavasi
# expected      kuvaajana
# categories            _
# Name: 77, dtype: object
# 2
# lemma                         toimia
# got                      toimineella
# expected                 toimineella
# categories    V;ON+ESS;SG;V.PTCP;ACT
# Name: 78, dtype: object
# 0
# lemma                         toimia
# got                      toimineella
# expected                 toimineella
# categories    V;ON+ESS;SG;V.PTCP;ACT
# Name: 78, dtype: object
# 1
# lemma                         toimia
# got                      toimineella
# expected                 toimineella
# categories    V;ON+ESS;SG;V.PTCP;ACT
# Name: 78, dtype: object
# 2
# lemma                  Minttu
# got                  Mintulla
# expected             Mintulla
# categories    PROPN;ON+ESS;SG
# Name: 79, dtype: object
# 0
# lemma                  Minttu
# got                  Mintulla
# expected             Mintulla
# categories    PROPN;ON+ESS;SG
# Name: 79, dtype: object
# 1
# lemma                  Minttu
# got                  Mintulla
# expected             Mintulla
# categories    PROPN;ON+ESS;SG
# Name: 79, dtype: object
# 2
# lemma                             olla
# got                             olikin
# expected                        olikin
# categories    AUX;IND;SG;3;PST;FIN;ACT
# Name: 80, dtype: object
# 0
# lemma                             olla
# got                             olikin
# expected                        olikin
# categories    AUX;IND;SG;3;PST;FIN;ACT
# Name: 80, dtype: object
# 1
# lemma                             olla
# got                             olikin
# expected                        olikin
# categories    AUX;IND;SG;3;PST;FIN;ACT
# Name: 80, dtype: object
# 2
# lemma         hieman
# got           hieman
# expected      hieman
# categories       ADV
# Name: 81, dtype: object
# 0
# lemma         hieman
# got           hieman
# expected      hieman
# categories       ADV
# Name: 81, dtype: object
# 1
# lemma         hieman
# got           hieman
# expected      hieman
# categories       ADV
# Name: 81, dtype: object
# 2
# lemma           tekninen
# got             teknisiä
# expected        teknisiä
# categories    ADJ;PRT;PL
# Name: 82, dtype: object
# 0
# lemma           tekninen
# got             teknisiä
# expected        teknisiä
# categories    ADJ;PRT;PL
# Name: 82, dtype: object
# 1
# lemma           tekninen
# got             teknisiä
# expected        teknisiä
# categories    ADJ;PRT;PL
# Name: 82, dtype: object
# 2
# lemma          ongelma
# got            onnelta
# expected      ongelmia
# categories           _
# Name: 83, dtype: object
# 0
# lemma          ongelma
# got            onnelta
# expected      ongelmia
# categories           _
# Name: 83, dtype: object
# 1
# lemma          ongelma
# got            onnelta
# expected      ongelmia
# categories           _
# Name: 83, dtype: object
# 2
# lemma                 kamera
# got                 kamerani
# expected            kamerani
# categories    N;GEN;SG;PSS1S
# Name: 84, dtype: object
# 0
# lemma                 kamera
# got                 kamerani
# expected            kamerani
# categories    N;GEN;SG;PSS1S
# Name: 84, dtype: object
# 1
# lemma                 kamera
# got                 kamerani
# expected            kamerani
# categories    N;GEN;SG;PSS1S
# Name: 84, dtype: object
# 2
# lemma         kanssa
# got           kanssa
# expected      kanssa
# categories       ADP
# Name: 85, dtype: object
# 0
# lemma         kanssa
# got           kanssa
# expected      kanssa
# categories       ADP
# Name: 85, dtype: object
# 1
# lemma         kanssa
# got           kanssa
# expected      kanssa
# categories       ADP
# Name: 85, dtype: object
# 2
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 86, dtype: object
# 0
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 86, dtype: object
# 1
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 86, dtype: object
# 2
# lemma         jumittua
# got            Laistun
# expected      Jumituin
# categories           _
# Name: 87, dtype: object
# 0
# lemma         jumittua
# got            Laistun
# expected      Jumituin
# categories           _
# Name: 87, dtype: object
# 1
# lemma         jumittua
# got            Laistun
# expected      Jumituin
# categories           _
# Name: 87, dtype: object
# 2
# lemma         heti
# got           heti
# expected      heti
# categories     ADV
# Name: 88, dtype: object
# 0
# lemma         heti
# got           heti
# expected      heti
# categories     ADV
# Name: 88, dtype: object
# 1
# lemma         heti
# got           heti
# expected      heti
# categories     ADV
# Name: 88, dtype: object
# 2
# lemma           ensimmäinen
# got           ensimmäiselle
# expected      ensimmäiselle
# categories    ADJ;AT+ALL;SG
# Name: 89, dtype: object
# 0
# lemma           ensimmäinen
# got           ensimmäiselle
# expected      ensimmäiselle
# categories    ADJ;AT+ALL;SG
# Name: 89, dtype: object
# 1
# lemma           ensimmäinen
# got           ensimmäiselle
# expected      ensimmäiselle
# categories    ADJ;AT+ALL;SG
# Name: 89, dtype: object
# 2
# lemma                                nähdä
# got                            näkemälleni
# expected                       näkemälleni
# categories    V;AT+ALL;SG;V.PTCP;ACT;PSS1S
# Name: 90, dtype: object
# 0
# lemma                                nähdä
# got                            näkemälleni
# expected                       näkemälleni
# categories    V;AT+ALL;SG;V.PTCP;ACT;PSS1S
# Name: 90, dtype: object
# 1
# lemma                                nähdä
# got                            näkemälleni
# expected                       näkemälleni
# categories    V;AT+ALL;SG;V.PTCP;ACT;PSS1S
# Name: 90, dtype: object
# 2
# lemma               seinä
# got              seinälle
# expected         seinälle
# categories    N;AT+ALL;SG
# Name: 91, dtype: object
# 0
# lemma               seinä
# got              seinälle
# expected         seinälle
# categories    N;AT+ALL;SG
# Name: 91, dtype: object
# 1
# lemma               seinä
# got              seinälle
# expected         seinälle
# categories    N;AT+ALL;SG
# Name: 91, dtype: object
# 2
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 92, dtype: object
# 0
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 92, dtype: object
# 1
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 92, dtype: object
# 2
# lemma            hylly
# got               Lölä
# expected      Hyllyllä
# categories           _
# Name: 93, dtype: object
# 0
# lemma            hylly
# got               Lölä
# expected      Hyllyllä
# categories           _
# Name: 93, dtype: object
# 1
# lemma            hylly
# got               Lölä
# expected      Hyllyllä
# categories           _
# Name: 93, dtype: object
# 2
# lemma                             olla
# got                                oli
# expected                           oli
# categories    AUX;IND;SG;3;PST;FIN;ACT
# Name: 94, dtype: object
# 0
# lemma                             olla
# got                                oli
# expected                           oli
# categories    AUX;IND;SG;3;PST;FIN;ACT
# Name: 94, dtype: object
# 1
# lemma                             olla
# got                                oli
# expected                           oli
# categories    AUX;IND;SG;3;PST;FIN;ACT
# Name: 94, dtype: object
# 2
# lemma                  H&M
# got                    H&M
# expected               H&M
# categories    PROPN;NOM;SG
# Name: 95, dtype: object
# 0
# lemma                  H&M
# got                    H&M
# expected               H&M
# categories    PROPN;NOM;SG
# Name: 95, dtype: object
# 1
# lemma                  H&M
# got                    H&M
# expected               H&M
# categories    PROPN;NOM;SG
# Name: 95, dtype: object
# 2
# lemma                 Home
# got                   Home
# expected              Home
# categories    PROPN;NOM;SG
# Name: 96, dtype: object
# 0
# lemma                 Home
# got                   Home
# expected              Home
# categories    PROPN;NOM;SG
# Name: 96, dtype: object
# 1
# lemma                 Home
# got                   Home
# expected              Home
# categories    PROPN;NOM;SG
# Name: 96, dtype: object
# 2
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 97, dtype: object
# 0
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 97, dtype: object
# 1
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 97, dtype: object
# 2
# lemma         varsinkin
# got           varsinkin
# expected      varsinkin
# categories          ADV
# Name: 98, dtype: object
# 0
# lemma         varsinkin
# got           varsinkin
# expected      varsinkin
# categories          ADV
# Name: 98, dtype: object
# 1
# lemma         varsinkin
# got           varsinkin
# expected      varsinkin
# categories          ADV
# Name: 98, dtype: object
# 2
# lemma                tuo
# got                  nuo
# expected             nuo
# categories    PRO;NOM;PL
# Name: 99, dtype: object
# 0
# lemma                tuo
# got                  nuo
# expected             nuo
# categories    PRO;NOM;PL
# Name: 99, dtype: object
# 1
# lemma                tuo
# got                  nuo
# expected             nuo
# categories    PRO;NOM;PL
# Name: 99, dtype: object
# 2
# lemma         pinkki
# got           pikkin
# expected      pinkin
# categories         _
# Name: 100, dtype: object
# 0
# lemma         pinkki
# got           pikkin
# expected      pinkin
# categories         _
# Name: 100, dtype: object
# 1
# lemma         pinkki
# got           pikkin
# expected      pinkin
# categories         _
# Name: 100, dtype: object
# 2
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 101, dtype: object
# 0
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 101, dtype: object
# 1
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 101, dtype: object
# 2
# lemma          vaaleapunainen
# got           vaaleanpunaisen
# expected      vaaleanpunaisen
# categories           N;GEN;SG
# Name: 102, dtype: object
# 0
# lemma          vaaleapunainen
# got           vaaleanpunaisen
# expected      vaaleanpunaisen
# categories           N;GEN;SG
# Name: 102, dtype: object
# 1
# lemma          vaaleapunainen
# got           vaaleanpunaisen
# expected      vaaleanpunaisen
# categories           N;GEN;SG
# Name: 102, dtype: object
# 2
# lemma                sävy
# got              sävyillä
# expected         sävyillä
# categories    N;ON+ESS;PL
# Name: 103, dtype: object
# 0
# lemma                sävy
# got              sävyillä
# expected         sävyillä
# categories    N;ON+ESS;PL
# Name: 103, dtype: object
# 1
# lemma                sävy
# got              sävyillä
# expected         sävyillä
# categories    N;ON+ESS;PL
# Name: 103, dtype: object
# 2
# lemma                   koristella
# got                    koristellut
# expected               koristellut
# categories    V;NOM;PL;V.PTCP;PASS
# Name: 104, dtype: object
# 0
# lemma                   koristella
# got                    koristellut
# expected               koristellut
# categories    V;NOM;PL;V.PTCP;PASS
# Name: 104, dtype: object
# 1
# lemma                   koristella
# got                    koristellut
# expected               koristellut
# categories    V;NOM;PL;V.PTCP;PASS
# Name: 104, dtype: object
# 2
# lemma         sisustusjuttu
# got           sisustusjutut
# expected      sisustusjutut
# categories         N;NOM;PL
# Name: 105, dtype: object
# 0
# lemma         sisustusjuttu
# got           sisustusjutut
# expected      sisustusjutut
# categories         N;NOM;PL
# Name: 105, dtype: object
# 1
# lemma         sisustusjuttu
# got           sisustusjutut
# expected      sisustusjutut
# categories         N;NOM;PL
# Name: 105, dtype: object
# 2
# lemma            vedota
# got              veitta
# expected      vetosivat
# categories            _
# Name: 106, dtype: object
# 0
# lemma            vedota
# got              veitta
# expected      vetosivat
# categories            _
# Name: 106, dtype: object
# 1
# lemma            vedota
# got              veitta
# expected      vetosivat
# categories            _
# Name: 106, dtype: object
# 2
# lemma                    minä
# got                    minuun
# expected               minuun
# categories    PRO;IN+ALL;SG;1
# Name: 107, dtype: object
# 0
# lemma                    minä
# got                    minuun
# expected               minuun
# categories    PRO;IN+ALL;SG;1
# Name: 107, dtype: object
# 1
# lemma                    minä
# got                    minuun
# expected               minuun
# categories    PRO;IN+ALL;SG;1
# Name: 107, dtype: object
# 2
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 108, dtype: object
# 0
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 108, dtype: object
# 1
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 108, dtype: object
# 2
# lemma                 se
# got                   Se
# expected              Se
# categories    PRO;NOM;SG
# Name: 109, dtype: object
# 0
# lemma                 se
# got                   Se
# expected              Se
# categories    PRO;NOM;SG
# Name: 109, dtype: object
# 1
# lemma                 se
# got                   Se
# expected              Se
# categories    PRO;NOM;SG
# Name: 109, dtype: object
# 2
# lemma           sisäinen
# got             sisäinen
# expected        sisäinen
# categories    ADJ;NOM;SG
# Name: 110, dtype: object
# 0
# lemma           sisäinen
# got             sisäinen
# expected        sisäinen
# categories    ADJ;NOM;SG
# Name: 110, dtype: object
# 1
# lemma           sisäinen
# got             sisäinen
# expected        sisäinen
# categories    ADJ;NOM;SG
# Name: 110, dtype: object
# 2
# lemma                  lapsi
# got                  lapseni
# expected             lapseni
# categories    N;NOM;SG;PSS1S
# Name: 111, dtype: object
# 0
# lemma                  lapsi
# got                  lapseni
# expected             lapseni
# categories    N;NOM;SG;PSS1S
# Name: 111, dtype: object
# 1
# lemma                  lapsi
# got                  lapseni
# expected             lapseni
# categories    N;NOM;SG;PSS1S
# Name: 111, dtype: object
# 2
# lemma                           ei
# got                             ei
# expected                        ei
# categories    AUX;SG;3;NEG;FIN;ACT
# Name: 112, dtype: object
# 0
# lemma                           ei
# got                             ei
# expected                        ei
# categories    AUX;SG;3;NEG;FIN;ACT
# Name: 112, dtype: object
# 1
# lemma                           ei
# got                             ei
# expected                        ei
# categories    AUX;SG;3;NEG;FIN;ACT
# Name: 112, dtype: object
# 2
# lemma         vaan
# got           vaan
# expected      vaan
# categories     ADV
# Name: 113, dtype: object
# 0
# lemma         vaan
# got           vaan
# expected      vaan
# categories     ADV
# Name: 113, dtype: object
# 1
# lemma         vaan
# got           vaan
# expected      vaan
# categories     ADV
# Name: 113, dtype: object
# 2
# lemma          suostua
# got           suomasta
# expected        suostu
# categories           _
# Name: 114, dtype: object
# 0
# lemma          suostua
# got           suomasta
# expected        suostu
# categories           _
# Name: 114, dtype: object
# 1
# lemma          suostua
# got           suomasta
# expected        suostu
# categories           _
# Name: 114, dtype: object
# 2
# lemma                       kadota
# got                      katoamaan
# expected                 katoamaan
# categories    V;IN+ALL;SG;NFIN;ACT
# Name: 115, dtype: object
# 0
# lemma                       kadota
# got                      katoamaan
# expected                 katoamaan
# categories    V;IN+ALL;SG;NFIN;ACT
# Name: 115, dtype: object
# 1
# lemma                       kadota
# got                      katoamaan
# expected                 katoamaan
# categories    V;IN+ALL;SG;NFIN;ACT
# Name: 115, dtype: object
# 2
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 116, dtype: object
# 0
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 116, dtype: object
# 1
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 116, dtype: object
# 2
# lemma                   oma
# got                   Omaan
# expected              Omaan
# categories    ADJ;IN+ALL;SG
# Name: 117, dtype: object
# 0
# lemma                   oma
# got                   Omaan
# expected              Omaan
# categories    ADJ;IN+ALL;SG
# Name: 117, dtype: object
# 1
# lemma                   oma
# got                   Omaan
# expected              Omaan
# categories    ADJ;IN+ALL;SG
# Name: 117, dtype: object
# 2
# lemma                    asunto
# got                   asuntooni
# expected              asuntooni
# categories    N;IN+ALL;SG;PSS1S
# Name: 118, dtype: object
# 0
# lemma                    asunto
# got                   asuntooni
# expected              asuntooni
# categories    N;IN+ALL;SG;PSS1S
# Name: 118, dtype: object
# 1
# lemma                    asunto
# got                   asuntooni
# expected              asuntooni
# categories    N;IN+ALL;SG;PSS1S
# Name: 118, dtype: object
# 2
# lemma                tuo
# got                 tuon
# expected            tuon
# categories    PRO;GEN;SG
# Name: 119, dtype: object
# 0
# lemma                tuo
# got                 tuon
# expected            tuon
# categories    PRO;GEN;SG
# Name: 119, dtype: object
# 1
# lemma                tuo
# got                 tuon
# expected            tuon
# categories    PRO;GEN;SG
# Name: 119, dtype: object
# 2
# lemma            värinen
# got              väriset
# expected         väriset
# categories    ADJ;NOM;PL
# Name: 120, dtype: object
# 0
# lemma            värinen
# got              väriset
# expected         väriset
# categories    ADJ;NOM;PL
# Name: 120, dtype: object
# 1
# lemma            värinen
# got              väriset
# expected         väriset
# categories    ADJ;NOM;PL
# Name: 120, dtype: object
# 2
# lemma            tyyny
# got             tyynyt
# expected        tyynyt
# categories    N;NOM;PL
# Name: 121, dtype: object
# 0
# lemma            tyyny
# got             tyynyt
# expected        tyynyt
# categories    N;NOM;PL
# Name: 121, dtype: object
# 1
# lemma            tyyny
# got             tyynyt
# expected        tyynyt
# categories    N;NOM;PL
# Name: 121, dtype: object
# 2
# lemma                           ei
# got                          eivät
# expected                     eivät
# categories    AUX;PL;3;NEG;FIN;ACT
# Name: 122, dtype: object
# 0
# lemma                           ei
# got                          eivät
# expected                     eivät
# categories    AUX;PL;3;NEG;FIN;ACT
# Name: 122, dtype: object
# 1
# lemma                           ei
# got                          eivät
# expected                     eivät
# categories    AUX;PL;3;NEG;FIN;ACT
# Name: 122, dtype: object
# 2
# lemma         mitenkään
# got           mitenkään
# expected      mitenkään
# categories          ADV
# Name: 123, dtype: object
# 0
# lemma         mitenkään
# got           mitenkään
# expected      mitenkään
# categories          ADV
# Name: 123, dtype: object
# 1
# lemma         mitenkään
# got           mitenkään
# expected      mitenkään
# categories          ADV
# Name: 123, dtype: object
# 2
# lemma              hurja
# got               hurjan
# expected          hurjan
# categories    ADJ;GEN;SG
# Name: 124, dtype: object
# 0
# lemma              hurja
# got               hurjan
# expected          hurjan
# categories    ADJ;GEN;SG
# Name: 124, dtype: object
# 1
# lemma              hurja
# got               hurjan
# expected          hurjan
# categories    ADJ;GEN;SG
# ...
# categories    PUNCT
# Name: 2384, dtype: object
# 1
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 2384, dtype: object
# 2
# lemma                katsoa
# got                  katsoa
# expected             katsoa
# categories    V;SG;NFIN;ACT
# Name: 2385, dtype: object
# 0
# lemma                katsoa
# got                  katsoa
# expected             katsoa
# categories    V;SG;NFIN;ACT
# Name: 2385, dtype: object
# 1
# lemma                katsoa
# got                  katsoa
# expected             katsoa
# categories    V;SG;NFIN;ACT
# Name: 2385, dtype: object
# 2
# lemma             valo
# got              valon
# expected         valon
# categories    N;GEN;SG
# Name: 2386, dtype: object
# 0
# lemma             valo
# got              valon
# expected         valon
# categories    N;GEN;SG
# Name: 2386, dtype: object
# 1
# lemma             valo
# got              valon
# expected         valon
# categories    N;GEN;SG
# Name: 2386, dtype: object
# 2
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 2387, dtype: object
# 0
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 2387, dtype: object
# 1
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 2387, dtype: object
# 2
# lemma            tuuli
# got             tuulen
# expected        tuulen
# categories    N;GEN;SG
# Name: 2388, dtype: object
# 0
# lemma            tuuli
# got             tuulen
# expected        tuulen
# categories    N;GEN;SG
# Name: 2388, dtype: object
# 1
# lemma            tuuli
# got             tuulen
# expected        tuulen
# categories    N;GEN;SG
# Name: 2388, dtype: object
# 2
# lemma           leikki
# got           leikkiin
# expected       leikkiä
# categories           _
# Name: 2389, dtype: object
# 0
# lemma           leikki
# got           leikkiin
# expected       leikkiä
# categories           _
# Name: 2389, dtype: object
# 1
# lemma           leikki
# got           leikkiin
# expected       leikkiä
# categories           _
# Name: 2389, dtype: object
# 2
# lemma            lehvästö
# got           lehvästössä
# expected      lehvästössä
# categories    N;IN+ESS;SG
# Name: 2390, dtype: object
# 0
# lemma            lehvästö
# got           lehvästössä
# expected      lehvästössä
# categories    N;IN+ESS;SG
# Name: 2390, dtype: object
# 1
# lemma            lehvästö
# got           lehvästössä
# expected      lehvästössä
# categories    N;IN+ESS;SG
# Name: 2390, dtype: object
# 2
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 2391, dtype: object
# 0
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 2391, dtype: object
# 1
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 2391, dtype: object
# 2
# lemma                 antaa
# got                   antaa
# expected              antaa
# categories    V;SG;NFIN;ACT
# Name: 2392, dtype: object
# 0
# lemma                 antaa
# got                   antaa
# expected              antaa
# categories    V;SG;NFIN;ACT
# Name: 2392, dtype: object
# 1
# lemma                 antaa
# got                   antaa
# expected              antaa
# categories    V;SG;NFIN;ACT
# Name: 2392, dtype: object
# 2
# lemma         peipponen
# got           peipposen
# expected      peipposen
# categories     N;GEN;SG
# Name: 2393, dtype: object
# 0
# lemma         peipponen
# got           peipposen
# expected      peipposen
# categories     N;GEN;SG
# Name: 2393, dtype: object
# 1
# lemma         peipponen
# got           peipposen
# expected      peipposen
# categories     N;GEN;SG
# Name: 2393, dtype: object
# 2
# lemma                laulaa
# got                  laulaa
# expected             laulaa
# categories    V;SG;NFIN;ACT
# Name: 2394, dtype: object
# 0
# lemma                laulaa
# got                  laulaa
# expected             laulaa
# categories    V;SG;NFIN;ACT
# Name: 2394, dtype: object
# 1
# lemma                laulaa
# got                  laulaa
# expected             laulaa
# categories    V;SG;NFIN;ACT
# Name: 2394, dtype: object
# 2
# lemma         sielu
# got           silun
# expected      sielu
# categories        _
# Name: 2395, dtype: object
# 0
# lemma         sielu
# got           silun
# expected      sielu
# categories        _
# Name: 2395, dtype: object
# 1
# lemma         sielu
# got           silun
# expected      sielu
# categories        _
# Name: 2395, dtype: object
# 2
# lemma         pullolleen
# got           pullolleen
# expected      pullolleen
# categories           ADV
# Name: 2396, dtype: object
# 0
# lemma         pullolleen
# got           pullolleen
# expected      pullolleen
# categories           ADV
# Name: 2396, dtype: object
# 1
# lemma         pullolleen
# got           pullolleen
# expected      pullolleen
# categories           ADV
# Name: 2396, dtype: object
# 2
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 2397, dtype: object
# 0
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 2397, dtype: object
# 1
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 2397, dtype: object
# 2
# lemma               metsä
# got              Metsässä
# expected         Metsässä
# categories    N;IN+ESS;SG
# Name: 2398, dtype: object
# 0
# lemma               metsä
# got              Metsässä
# expected         Metsässä
# categories    N;IN+ESS;SG
# Name: 2398, dtype: object
# 1
# lemma               metsä
# got              Metsässä
# expected         Metsässä
# categories    N;IN+ESS;SG
# Name: 2398, dtype: object
# 2
# lemma                             olla
# got                                oli
# expected                           oli
# categories    AUX;IND;SG;3;PST;FIN;ACT
# Name: 2399, dtype: object
# 0
# lemma                             olla
# got                                oli
# expected                           oli
# categories    AUX;IND;SG;3;PST;FIN;ACT
# Name: 2399, dtype: object
# 1
# lemma                             olla
# got                                oli
# expected                           oli
# categories    AUX;IND;SG;3;PST;FIN;ACT
# Name: 2399, dtype: object
# 2
# lemma           lampi
# got           lallain
# expected        lampi
# categories          _
# Name: 2400, dtype: object
# 0
# lemma           lampi
# got           lallain
# expected        lampi
# categories          _
# Name: 2400, dtype: object
# 1
# lemma           lampi
# got           lallain
# expected        lampi
# categories          _
# Name: 2400, dtype: object
# 2
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 2401, dtype: object
# 0
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 2401, dtype: object
# 1
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 2401, dtype: object
# 2
# lemma           kallio
# got             kallio
# expected        kallio
# categories    N;NOM;SG
# Name: 2402, dtype: object
# 0
# lemma           kallio
# got             kallio
# expected        kallio
# categories    N;NOM;SG
# Name: 2402, dtype: object
# 1
# lemma           kallio
# got             kallio
# expected        kallio
# categories    N;NOM;SG
# Name: 2402, dtype: object
# 2
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 2403, dtype: object
# 0
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 2403, dtype: object
# 1
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 2403, dtype: object
# 2
# lemma          maailma
# got           maailman
# expected      maailman
# categories    N;GEN;SG
# Name: 2404, dtype: object
# 0
# lemma          maailma
# got           maailman
# expected      maailman
# categories    N;GEN;SG
# Name: 2404, dtype: object
# 1
# lemma          maailma
# got           maailman
# expected      maailman
# categories    N;GEN;SG
# Name: 2404, dtype: object
# 2
# lemma                  korkea
# got                korkeimmat
# expected           korkeimmat
# categories    ADJ;NOM;SPRL;PL
# Name: 2405, dtype: object
# 0
# lemma                  korkea
# got                korkeimmat
# expected           korkeimmat
# categories    ADJ;NOM;SPRL;PL
# Name: 2405, dtype: object
# 1
# lemma                  korkea
# got                korkeimmat
# expected           korkeimmat
# categories    ADJ;NOM;SPRL;PL
# Name: 2405, dtype: object
# 2
# lemma            koivu
# got             koivut
# expected        koivut
# categories    N;NOM;PL
# Name: 2406, dtype: object
# 0
# lemma            koivu
# got             koivut
# expected        koivut
# categories    N;NOM;PL
# Name: 2406, dtype: object
# 1
# lemma            koivu
# got             koivut
# expected        koivut
# categories    N;NOM;PL
# Name: 2406, dtype: object
# 2
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 2407, dtype: object
# 0
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 2407, dtype: object
# 1
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 2407, dtype: object
# 2
# lemma              pieni
# got                pieni
# expected           pieni
# categories    ADJ;NOM;SG
# Name: 2408, dtype: object
# 0
# lemma              pieni
# got                pieni
# expected           pieni
# categories    ADJ;NOM;SG
# Name: 2408, dtype: object
# 1
# lemma              pieni
# got                pieni
# expected           pieni
# categories    ADJ;NOM;SG
# Name: 2408, dtype: object
# 2
# lemma         salaperäinen
# got           salaperäisen
# expected      salaperäisen
# categories      ADJ;GEN;SG
# Name: 2409, dtype: object
# 0
# lemma         salaperäinen
# got           salaperäisen
# expected      salaperäisen
# categories      ADJ;GEN;SG
# Name: 2409, dtype: object
# 1
# lemma         salaperäinen
# got           salaperäisen
# expected      salaperäisen
# categories      ADJ;GEN;SG
# Name: 2409, dtype: object
# 2
# lemma           hämyinen
# got             hämyinen
# expected        hämyinen
# categories    ADJ;NOM;SG
# Name: 2410, dtype: object
# 0
# lemma           hämyinen
# got             hämyinen
# expected        hämyinen
# categories    ADJ;NOM;SG
# Name: 2410, dtype: object
# 1
# lemma           hämyinen
# got             hämyinen
# expected        hämyinen
# categories    ADJ;NOM;SG
# Name: 2410, dtype: object
# 2
# lemma         kuusikko
# got           kuusikko
# expected      kuusikko
# categories    N;NOM;SG
# Name: 2411, dtype: object
# 0
# lemma         kuusikko
# got           kuusikko
# expected      kuusikko
# categories    N;NOM;SG
# Name: 2411, dtype: object
# 1
# lemma         kuusikko
# got           kuusikko
# expected      kuusikko
# categories    N;NOM;SG
# Name: 2411, dtype: object
# 2
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 2412, dtype: object
# 0
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 2412, dtype: object
# 1
# lemma             .
# got               .
# expected          .
# categories    PUNCT
# Name: 2412, dtype: object
# 2
# lemma                 se
# got                   Se
# expected              Se
# categories    PRO;NOM;SG
# Name: 2413, dtype: object
# 0
# lemma                 se
# got                   Se
# expected              Se
# categories    PRO;NOM;SG
# Name: 2413, dtype: object
# 1
# lemma                 se
# got                   Se
# expected              Se
# categories    PRO;NOM;SG
# Name: 2413, dtype: object
# 2
# lemma                             olla
# got                                oli
# expected                           oli
# categories    AUX;IND;SG;3;PST;FIN;ACT
# Name: 2414, dtype: object
# 0
# lemma                             olla
# got                                oli
# expected                           oli
# categories    AUX;IND;SG;3;PST;FIN;ACT
# Name: 2414, dtype: object
# 1
# lemma                             olla
# got                                oli
# expected                           oli
# categories    AUX;IND;SG;3;PST;FIN;ACT
# Name: 2414, dtype: object
# 2
# lemma                 minä
# got                 meidän
# expected            meidän
# categories    PRO;GEN;PL;1
# Name: 2415, dtype: object
# 0
# lemma                 minä
# got                 meidän
# expected            meidän
# categories    PRO;GEN;PL;1
# Name: 2415, dtype: object
# 1
# lemma                 minä
# got                 meidän
# expected            meidän
# categories    PRO;GEN;PL;1
# Name: 2415, dtype: object
# 2
# lemma                  metsä
# got                 metsämme
# expected            metsämme
# categories    N;NOM;SG;PSS1P
# Name: 2416, dtype: object
# 0
# lemma                  metsä
# got                 metsämme
# expected            metsämme
# categories    N;NOM;SG;PSS1P
# Name: 2416, dtype: object
# 1
# lemma                  metsä
# got                 metsämme
# expected            metsämme
# categories    N;NOM;SG;PSS1P
# Name: 2416, dtype: object
# 2
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 2417, dtype: object
# 0
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 2417, dtype: object
# 1
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 2417, dtype: object
# 2
# lemma         miniuniversumi
# got           miniuniversumi
# expected      miniuniversumi
# categories          N;NOM;SG
# Name: 2418, dtype: object
# 0
# lemma         miniuniversumi
# got           miniuniversumi
# expected      miniuniversumi
# categories          N;NOM;SG
# Name: 2418, dtype: object
# 1
# lemma         miniuniversumi
# got           miniuniversumi
# expected      miniuniversumi
# categories          N;NOM;SG
# Name: 2418, dtype: object
# 2
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 2419, dtype: object
# 0
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 2419, dtype: object
# 1
# lemma             ,
# got               ,
# expected          ,
# categories    PUNCT
# Name: 2419, dtype: object
# 2
# lemma                  joka
# got                   jossa
# expected              jossa
# categories    PRO;IN+ESS;SG
# Name: 2420, dtype: object
# 0
# lemma                  joka
# got                   jossa
# expected              jossa
# categories    PRO;IN+ESS;SG
# Name: 2420, dtype: object
# 1
# lemma                  joka
# got                   jossa
# expected              jossa
# categories    PRO;IN+ESS;SG
# Name: 2420, dtype: object
# 2
# lemma                         löytyä
# got                           löytyi
# expected                      löytyi
# categories    V;IND;SG;3;PST;FIN;ACT
# Name: 2421, dtype: object
# 0
# lemma                         löytyä
# got                           löytyi
# expected                      löytyi
# categories    V;IND;SG;3;PST;FIN;ACT
# Name: 2421, dtype: object
# 1
# lemma                         löytyä
# got                           löytyi
# expected                      löytyi
# categories    V;IND;SG;3;PST;FIN;ACT
# Name: 2421, dtype: object
# 2
# lemma           paikka
# got             paikka
# expected        paikka
# categories    N;NOM;SG
# Name: 2422, dtype: object
# 0
# lemma           paikka
# got             paikka
# expected        paikka
# categories    N;NOM;SG
# Name: 2422, dtype: object
# 1
# lemma           paikka
# got             paikka
# expected        paikka
# categories    N;NOM;SG
# Name: 2422, dtype: object
# 2
# lemma              jokainen
# got              jokaiselle
# expected         jokaiselle
# categories    PRO;AT+ALL;SG
# Name: 2423, dtype: object
# 0
# lemma              jokainen
# got              jokaiselle
# expected         jokaiselle
# categories    PRO;AT+ALL;SG
# Name: 2423, dtype: object
# 1
# lemma              jokainen
# got              jokaiselle
# expected         jokaiselle
# categories    PRO;AT+ALL;SG
# Name: 2423, dtype: object
# 2
# lemma            mieliala
# got               mililla
# expected      mielialalle
# categories              _
# Name: 2424, dtype: object
# 0
# lemma            mieliala
# got               mililla
# expected      mielialalle
# categories              _
# Name: 2424, dtype: object
# 1
# lemma            mieliala
# got               mililla
# expected      mielialalle
# categories              _
# Name: 2424, dtype: object
# 2
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 2425, dtype: object
# 0
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 2425, dtype: object
# 1
# lemma           ja
# got             ja
# expected        ja
# categories    CONJ
# Name: 2425, dtype: object
# 2
# lemma            tunnelma
# got           tunnelmalle
# expected      tunnelmalle
# categories    N;AT+ALL;SG
# Name: 2426, dtype: object
